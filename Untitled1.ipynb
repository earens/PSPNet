# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from matplotlib import image

# %%
from segmentation_models import PSPNet

model = PSPNet()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0513 15:57:12.718626 4452310464 module_wrapper.py:139] From /Users/Emilia/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0513 15:57:12.721246 4452310464 module_wrapper.py:139] From /Users/Emilia/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0513 15:57:12.725979 4452310464 module_wrapper.py:139] From /Users/Emilia/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...

# %%
PATH_train = Path.cwd()/"VOC2012"/"ImageSets"/"Segmentation"/"train.txt"
PATH_test = Path.cwd()/"VOC2012"/"ImageSets"/"Segmentation"/"val.txt"

PATH_train_data = Path.cwd()/"VOC2012"

train = open(PATH_train,"r")
train = [image[:-1] for image in train]

test = open(PATH_test,"r")
test = [image for image in test]

original_train = []
ground_truth_train = []

original_test = []
ground_truth_test = []

for im in listdir(str(PATH_train_data)+ '/' + 'SegmentationObject'):
    
    if im.split('.')[0] in list(train):
        
        img_data = image.imread(str(PATH_train_data)+ '/' + 'JPEGImages' + '/' + im.split('.')[0] + '.jpg')
        original_train.append(img_data)
        img_data = image.imread(str(PATH_train_data)+ '/' + 'SegmentationObject' + '/' + im)
        ground_truth_train.append(img_data)
        
    else:
        
        img_data = image.imread(str(PATH_train_data)+ '/' + 'JPEGImages' + '/' + im.split('.')[0] + '.jpg')
        original_test.append(img_data)
        img_data = image.imread(str(PATH_train_data)+ '/' + 'SegmentationObject' + '/' + im)
        ground_truth_test.append(img_data)

# %%
        
plt.imshow(original_train[10])
plt.show()

plt.imshow(ground_truth_train[10])
plt.show()


plt.imshow(original_test[10])
plt.show()

plt.imshow(ground_truth_test[10])
plt.show()
# Out:
# numpy.ndarray

# %%
print(original_train[0].shape)
print(ground_truth_train[0].shape)
# Out:
# (333, 500, 3)
# (333, 500, 3)

# %%
from PIL import Image  

size = [(i.shape[0],i.shape[1])for i in original_train]
print(min(size[0]),min(size[1]))
# Out:
# 333 366

# %%
from segmentation_models import PSPNet
from segmentation_models import get_preprocessing
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score

BACKBONE = 'resnet34'
preprocess_input = get_preprocessing(BACKBONE)

# load your data
x_train, y_train, x_val, y_val = original_train, ground_truth_train,original_test, ground_truth_test


# preprocess input
x_train = preprocess_input(x_train)
x_val = preprocess_input(x_val)

#print([(x.shape) for x in x_train] )

# define model
model = PSPNet(BACKBONE, encoder_weights='imagenet', input_shape=(None, None, 3))
model.compile('Adam', loss=bce_jaccard_loss, metrics=[iou_score])

# fit model
model.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    epochs=100,
    validation_data=(x_val, y_val),
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-0d425a00be85> in <module>
#      18
#      19 # define model
# ---> 20 model = PSPNet(BACKBONE, encoder_weights='imagenet', input_shape=(None, None, 3))
#      21 model.compile('Adam', loss=bce_jaccard_loss, metrics=[iou_score])
#      22
#
# ~/anaconda3/lib/python3.7/site-packages/segmentation_models/__init__.py in wrapper(*args, **kwargs)
#      32         kwargs['models'] = _KERAS_MODELS
#      33         kwargs['utils'] = _KERAS_UTILS
# ---> 34         return func(*args, **kwargs)
#      35
#      36     return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/segmentation_models/models/pspnet.py in PSPNet(backbone_name, input_shape, classes, activation, weights, encoder_weights, encoder_freeze, downsample_factor, psp_conv_filters, psp_pooling_type, psp_use_batchnorm, psp_dropout, **kwargs)
#     201
# ...
